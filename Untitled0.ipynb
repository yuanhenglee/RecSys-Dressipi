# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
project_root_path = '/content/drive/MyDrive/NCCU1102/WSM/proj3/RecSys-Dressipi/'

# %%
! cd /content/drive/MyDrive/NCCU1102/WSM/proj3/RecSys-Dressipi
! ls
# Out:
# drive  sample_data

# %%
# !python3 /content/drive/MyDrive/NCCU1102/WSM/proj3/RecSys-Dressipi/src/VSM/feature_generate.py --with_purchase
# !python3 /content/drive/MyDrive/NCCU1102/WSM/proj3/RecSys-Dressipi/src/VSM/feature_generate.py --session_path dataset/test_sessions.pickle --output_path dataset/test_features/test_s
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/NCCU1102/WSM/proj3/RecSys-Dressipi/src/VSM/feature_generate.py", line 101, in <module>
#     with open(session_path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/train_sessions.pickle'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/NCCU1102/WSM/proj3/RecSys-Dressipi/src/VSM/feature_generate.py", line 112, in <module>
#     raise "Fail to load pickles."
# TypeError: exceptions must derive from BaseException
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/NCCU1102/WSM/proj3/RecSys-Dressipi/src/VSM/feature_generate.py", line 101, in <module>
#     with open(session_path, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/test_sessions.pickle'
#
# During handling of the above exception, another exception occurred:
#
# ...
